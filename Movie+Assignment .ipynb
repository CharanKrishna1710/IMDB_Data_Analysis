# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv('Movie+Assignment+Data.csv') 
# Write your code for importing the csv file here
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
rows,columns=movies.shape
print('rows=',rows)
print('columns=',columns)
movies.dtypes
# Out:
# rows= 5043
# columns= 28
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here
movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here
def con(i):
    x=movies.shape[0]
    i/=x
    i*=10000
    i=int(i)
    return i/100
movies.isnull().sum().apply(con)
# Out:
# color                         0.37
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.29
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.45
# actor_2_name                  0.25
# actor_1_facebook_likes        0.13
# gross                        17.52
# genres                        0.00
# actor_1_name                  0.13
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.45
# facenumber_in_poster          0.25
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.41
# language                      0.23
# country                       0.09
# content_rating                6.00
# budget                        9.75
# title_year                    2.14
# actor_2_facebook_likes        0.25
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
cols_to_drop=['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes','actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country','movie_imdb_link','aspect_ratio','plot_keywords']
modified_movies=movies.drop(columns=cols_to_drop)
modified_movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 4           Doug Walker                     NaN          NaN
# ...                 ...                     ...          ...
# 5038        Scott Smith                     1.0          NaN
# 5039                NaN                    43.0          NaN
# 5040   Benjamin Roberds                    13.0          NaN
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                genres     actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
l=list(modified_movies.isnull().sum()/movies.shape[0]*100>5)
print(l)
#print(list(modified_movies))
col_list=list(modified_movies)
s=set()
for i in range(len(l)):
    if(l[i]==True):
        val_list=modified_movies[col_list[i]].isnull()
        for j in range(len(list(val_list))):
            if(list(val_list)[j]):
                s.add(j)
s
# Out:
# [False, False, True, False, False, False, False, False, False, True, False, False, False]
# {4096,
#  4,
#  4100,
#  4109,
#  4111,
#  4112,
#  4113,
#  4115,
#  4116,
#  4119,
#  2071,
#  2073,
#  2075,
#  2077,
#  4126,
#  4127,
#  4125,
#  4129,
#  4131,
#  4132,
#  4133,
#  4134,
#  4135,
#  2088,
#  4136,
#  4137,
#  4138,
#  4139,
#  4140,
#  4142,
#  4143,
#  4145,
#  4146,
#  4148,
#  2100,
#  4150,
#  55,
#  4152,
#  4153,
#  4160,
#  4162,
#  4163,
#  4164,
#  4165,
#  4166,
#  4167,
#  2117,
#  4170,
#  2123,
#  4174,
#  4176,
#  4177,
#  2130,
#  4178,
#  84,
#  4179,
#  4185,
#  4186,
#  2139,
#  2143,
#  4191,
#  4193,
#  98,
#  4194,
#  2464,
#  4209,
#  4210,
#  4211,
#  4214,
#  4215,
#  2466,
#  4217,
#  4218,
#  4220,
#  4221,
#  4222,
#  4223,
#  4224,
#  4226,
#  4227,
#  2180,
#  4232,
#  4233,
#  4234,
#  4235,
#  4236,
#  4237,
#  2189,
#  2191,
#  4239,
#  4913,
#  4242,
#  4243,
#  4244,
#  4245,
#  4246,
#  2200,
#  4249,
#  4250,
#  4252,
#  4253,
# ...

# %%
len(s)
# Out:
# 1152

# %%
# Write your code for dropping the rows here
modified_movies_final=modified_movies.drop(list(s))
modified_movies_final
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# # -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
modified_movies_final['language'].replace(to_replace='NaN',value='English')
modified_movies_final
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
print('Number of rows retained=',modified_movies_final.shape[0])
print('Number of rows retained=',modified_movies_final.shape[0]/movies.shape[0]*100)
# Out:
# Number of rows retained= 3891
# Number of rows retained= 77.15645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# # Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
def mil(i):
    return i/1000000
modified_movies_final['budget']=modified_movies_final['budget'].apply(mil)
modified_movies_final['gross']=modified_movies_final['gross'].apply(mil)
modified_movies_final
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %% [markdown]
#   ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
modified_movies_final['profit']=modified_movies_final['gross']-modified_movies_final['budget']
modified_movies_final
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 1        Gore Verbinski                   302.0  309.404152
# 2            Sam Mendes                   602.0  200.074175
# 3     Christopher Nolan                   813.0  448.130642
# 5        Andrew Stanton                   462.0   73.058679
# ...                 ...                     ...         ...
# 5033      Shane Carruth                   143.0    0.424760
# 5034   Neill Dela Llana                    35.0    0.070071
# 5035   Robert Rodriguez                    56.0    2.040920
# 5037       Edward Burns                    14.0    0.004584
# 5042           Jon Gunn                    43.0    0.085222
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# 2               Action|Adventure|Thriller  Christoph Waltz
# ...

# %%
# Write your code for sorting the dataframe here
modified_movies_final.sort_values(by='profit',ascending=False,inplace=True)
modified_movies_final
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write code for profit vs budget plot here
plt.plot(modified_movies_final['profit'],modified_movies_final['budget'])

# %%
# Write your code to get the top 10 profiting movies here
top10=pd.DataFrame(modified_movies_final.iloc[:10,:])
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
top10.drop_duplicates(['movie_title','language'])
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# ...

# %%
# Write code for repeating subtask 2 here
modified_movies_final.drop_duplicates(subset=['movie_title','language'],inplace=True)

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
sorted_rating=pd.DataFrame(modified_movies_final.sort_values(by='imdb_score',ascending=False))
excluded_rows=list(sorted_rating['num_voted_users']>25000)
indices=list(sorted_rating.index)
for i in range(len(indices)):
    if(excluded_rows[i]==False):
        sorted_rating.drop(indices[i],inplace=True)
sorted_rating
top250=pd.DataFrame(sorted_rating.head(250))
top250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 1874      Steven Spielberg                   174.0   96.067179
# ...                    ...                     ...         ...
# 525         Alfonso Cuarón                   372.0   35.286428
# 1748          F. Gary Gray                   349.0  161.029270
# 353          John Lasseter                   191.0  245.823397
# 75              Doug Liman                   585.0  100.189501
# 1735         James Mangold                   291.0  119.518352
#
#                                          genres           actor_1_name  \
# 1937                                Crime|Drama         Morgan Freeman
# ...

# %%
# Write your code to extract top foreign language films from 'IMDb_Top_250' here
topforeign=pd.DataFrame(top250)
exclude=topforeign['language']!='English'
indices=list(exclude.index)
values=list(exclude.values)
for i in range(len(indices)):
    if(values[i]==False):
        topforeign.drop(indices[i],inplace=True)
topforeign
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4029                Fernando Meirelles                   214.0    7.563397
# 4747                    Akira Kurosawa                   153.0    0.269061
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 4921                      Majid Majidi                    46.0    0.925402
# 2970                 Wolfgang Petersen                    96.0   11.433134
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 1298                Jean-Pierre Jeunet                   242.0   33.201661
# 4659                    Asghar Farhadi                   354.0    7.098492
# 4105                    Chan-wook Park                   305.0    2.181290
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %%
for i in list(topforeign['movie_title']):
    if('Veer-Zaara') in i:
        print("True")
# Out:
# True

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here
from statistics import mean
dir_groups= modified_movies_final.groupby(['director_name'])
dir_groups_df=pd.DataFrame(dir_groups)
mean_list=[]
for i in range(dir_groups_df.shape[0]):
    mean_list.append(mean(list(dir_groups_df[1][i]['imdb_score'])))
dir_groups_df['mean']=mean_list
dir_groups_df.sort_values(by='mean',ascending=False).head(10)
# Out:
#                       0                                                  1  \
# 216     Charles Chaplin          director_name  num_critic_for_reviews ...
# 1675          Tony Kaye       director_name  num_critic_for_reviews    ...
# 1017       Majid Majidi       director_name  num_critic_for_reviews    ...
# 302     Damien Chazelle          director_name  num_critic_for_reviews ...
# 45     Alfred Hitchcock           director_name  num_critic_for_reviews...
# 1440         Ron Fricke       director_name  num_critic_for_reviews    ...
# 1498       Sergio Leone       director_name  num_critic_for_reviews  gr...
# 260   Christopher Nolan            director_name  num_critic_for_review...
# 103      Asghar Farhadi         director_name  num_critic_for_reviews  ...
# 1467     S.S. Rajamouli         director_name  num_critic_for_reviews  ...
#
#           mean
# 216   8.600000
# 1675  8.600000
# 1017  8.500000
# 302   8.500000
# 45    8.500000
# 1440  8.500000
# 1498  8.433333
# ...

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
genre_df=pd.DataFrame(modified_movies_final)
def spt(s):
        l=s.split('|')
        if(len(l)==1):
            l.append(l[0])
        return l[0]
def spt1(s):
        l=s.split('|')
        if(len(l)==1):
            l.append(l[0])
        return l[1]
genre_df['genre1']=genre_df['genres'].apply(spt)
genre_df['genre2']=genre_df['genres'].apply(spt1)
genre_df
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
#movies_by_segment = # Write your code for grouping the dataframe here
genre_grouped_df=genre_df.groupby(['genre1','genre2'])
pd.DataFrame(genre_grouped_df)
# Out:
#                         0                                                  1
# 0        (Action, Action)            director_name  num_critic_for_review...
# 1     (Action, Adventure)              director_name  num_critic_for_revi...
# 2     (Action, Animation)             director_name  num_critic_for_revie...
# 3     (Action, Biography)             director_name  num_critic_for_revie...
# 4        (Action, Comedy)           director_name  num_critic_for_reviews...
# ..                    ...                                                ...
# 98      (Romance, Sci-Fi)      director_name  num_critic_for_reviews     ...
# 99       (Sci-Fi, Sci-Fi)          director_name  num_critic_for_reviews ...
# 100    (Sci-Fi, Thriller)              director_name  num_critic_for_revi...
# 101  (Thriller, Thriller)           director_name  num_critic_for_reviews...
# 102    (Western, Western)         director_name  num_critic_for_reviews  ...
#
# [103 rows x 2 columns]

# %%
#PopGenre = # Write your code for getting the 5 most popular combo of genres here
pop_genre=genre_grouped_df.mean('gross').sort_values('gross',ascending=False).head(5)
pop_genre
# Out:
#                      num_critic_for_reviews       gross  num_voted_users  \
# genre1    genre2
# Family    Sci-Fi                 215.000000  434.949459    281842.000000
# Adventure Sci-Fi                 344.375000  228.627758    290322.500000
#           Animation              170.017391  115.949069    137183.513043
#           Family                 195.580645  110.942298    150473.290323
# Action    Adventure              222.283208  107.880651    179287.451128
#
#                      num_user_for_reviews      budget   title_year  \
# genre1    genre2
# Family    Sci-Fi               515.000000   10.500000  1982.000000
# Adventure Sci-Fi               915.500000  104.500000  2007.750000
#           Animation            241.652174  106.353913  2006.339130
#           Family               492.806452   94.897742  2003.096774
# Action    Adventure            577.330827   98.147904  2002.092732
#
#                      imdb_score  movie_facebook_likes      profit
# genre1    genre2
# ...

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here

Meryl_Streep=pd.DataFrame(modified_movies_final[modified_movies_final['actor_1_name']=='Meryl Streep'])
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1408   David Frankel                   208.0  124.732962
# 1575  Sydney Pollack                    66.0   87.100000
# 1204     Nora Ephron                   252.0   94.125426
# 1618   David Frankel                   234.0   63.536011
# 410     Nancy Meyers                   187.0  112.703470
# 2781  Phyllida Lloyd                   331.0   29.959436
# 1925  Stephen Daldry                   174.0   41.597830
# 3135   Robert Altman                   211.0   20.338609
# 1106   Curtis Hanson                    42.0   46.815748
# 1674   Carl Franklin                    64.0   23.209440
# 1483  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 1408             Comedy|Drama|Romance  Meryl Streep
# 1575          Biography|Drama|Romance  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1618             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
# Include all movies in which Leo_Caprio is the lead
Leo_Caprio = pd.DataFrame(modified_movies_final[modified_movies_final['actor_1_name']=='Leonardo DiCaprio'])
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 26            James Cameron                   315.0  658.672302
# 97        Christopher Nolan                   642.0  292.568851
# 911        Steven Spielberg                   194.0  164.435221
# 296       Quentin Tarantino                   765.0  162.804648
# 179   Alejandro G. Iñárritu                   556.0  183.635922
# 452         Martin Scorsese                   490.0  127.968405
# 361         Martin Scorsese                   352.0  132.373442
# 50             Baz Luhrmann                   490.0  144.812796
# 2757           Baz Luhrmann                   106.0   46.338728
# 1422        Randall Wallace                    83.0   56.876365
# 308         Martin Scorsese                   606.0  116.866727
# 1453         Clint Eastwood                   392.0   37.304950
# 257         Martin Scorsese                   267.0  102.608827
# 2067             Jerry Zaks                    45.0   12.782508
# ...

# %%
# Include all movies in which Brad_Pitt is the lead
Brad_Pitt = pd.DataFrame(modified_movies_final[modified_movies_final['actor_1_name']=='Brad Pitt'])
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 400       Steven Soderbergh                   186.0  183.405771
# 255              Doug Liman                   233.0  186.336103
# 940             Neil Jordan                   120.0  105.264608
# 470              David Ayer                   406.0   85.707116
# 254       Steven Soderbergh                   198.0  125.531634
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 2682         Andrew Dominik                   414.0   14.938570
# 2898             Tony Scott                   122.0   12.281500
# 2333    Angelina Jolie Pitt                   131.0    0.531009
# 1490        Terrence Malick                   584.0   13.303319
# 101           David Fincher                   362.0  127.490802
# 683           David Fincher                   315.0   37.023395
# 1722         Andrew Dominik                   273.0    3.904982
# 611     Jean-Jacques Annaud                    76.0   37.901509
# ...

# %%
# Write your code for combining the three dataframes here
combined_df=pd.concat([Brad_Pitt,Leo_Caprio,Meryl_Streep])
combined_df
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 400       Steven Soderbergh                   186.0  183.405771
# 255              Doug Liman                   233.0  186.336103
# 940             Neil Jordan                   120.0  105.264608
# 470              David Ayer                   406.0   85.707116
# 254       Steven Soderbergh                   198.0  125.531634
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 2682         Andrew Dominik                   414.0   14.938570
# 2898             Tony Scott                   122.0   12.281500
# 2333    Angelina Jolie Pitt                   131.0    0.531009
# 1490        Terrence Malick                   584.0   13.303319
# 101           David Fincher                   362.0  127.490802
# 683           David Fincher                   315.0   37.023395
# 1722         Andrew Dominik                   273.0    3.904982
# 611     Jean-Jacques Annaud                    76.0   37.901509
# ...

# %%
# Write your code for grouping the combined dataframe here
grouped_df=pd.DataFrame(combined_df.groupby('actor_1_name'))
grouped_df
# Out:
#                    0                                                  1
# 0          Brad Pitt                director_name  num_critic_for_re...
# 1  Leonardo DiCaprio                director_name  num_critic_for_re...
# 2       Meryl Streep         director_name  num_critic_for_reviews  ...

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
combined_df.groupby('actor_1_name').mean(['num_critic_for_reviews','num_users_for_review'])
# Out:
#                    num_critic_for_reviews       gross  num_voted_users  \
# actor_1_name
# Brad Pitt                      245.000000   66.321449    283583.823529
# Leonardo DiCaprio              322.200000  124.788449    445910.150000
# Meryl Streep                   181.454545   59.919727     73545.545455
#
#                    num_user_for_reviews     budget   title_year  imdb_score  \
# actor_1_name
# Brad Pitt                    742.352941  69.294118  2004.352941    7.152941
# Leonardo DiCaprio            922.550000  81.325000  2005.100000    7.505000
# Meryl Streep                 297.181818  34.454545  2003.545455    6.745455
#
#                    movie_facebook_likes     profit
# actor_1_name
# Brad Pitt                  14051.764706  -2.972669
# Leonardo DiCaprio          49050.000000  43.463449
# Meryl Streep                2934.090909  25.465182

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
def decade(year):
    return str(int(year))[:-1]+'0'
decade_df=pd.DataFrame(modified_movies_final)
decade_df['decade']=decade_df['title_year'].apply(lambda x:decade(x) if(pd.notnull(x)) else x)
decade_df
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
# Write your code for creating the data frame df_by_decade here 
sum_voted=list(decade_df.groupby('decade',squeeze=False)['num_voted_users'].sum())
df_by_decade=pd.DataFrame(decade_df.groupby('decade',squeeze=False))
df_by_decade['sum_votes']=sum_voted
df_by_decade
# Out:
#       0                                                  1  sum_votes
# 0  1920            director_name  num_critic_for_review...     116392
# 1  1930           director_name  num_critic_for_reviews...     804839
# 2  1940            director_name  num_critic_for_review...     230838
# 3  1950           director_name  num_critic_for_reviews...     678336
# 4  1960               director_name  num_critic_for_rev...    2983442
# 5  1970               director_name  num_critic_for_rev...    8269834
# 6  1980               director_name  num_critic_for_rev...   19344381
# 7  1990           director_name  num_critic_for_reviews...   69635868
# 8  2000            director_name  num_critic_for_review...  166045528
# 9  2010           director_name  num_critic_for_reviews...  116240517

# %%
plt.plot(df_by_decade[0],df_by_decade['sum_votes'])
